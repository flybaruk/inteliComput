# %%
import pandas as pd
import io
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('simulacao-Main.csv')

# --- Passo 2: Calcular a média de 'Score' a cada 10 runs ---
df['run_group'] = (df.index // 10)
average_scores = df.groupby('run_group')['Score'].mean()


# --- Passo 3: Preparar os dados para o gráfico ---
# Criar uma lista de rótulos descritivos para o eixo X do gráfico
group_labels = [f'Runs {i*10+1}-{(i+1)*10}' for i in average_scores.index]


# --- Passo 4: Criar o gráfico de barras dos grupos ---
plt.figure(figsize=(10, 6))

# Usamos os rótulos que criamos no eixo X e as médias no eixo Y
plt.bar(group_labels, average_scores, color='teal')

# Adiciona uma linha horizontal no zero
plt.axhline(0, color='grey', linewidth=0.8)

# Adiciona títulos e rótulos
plt.title('Média de Score por Grupo de 10 Simulações Main')
plt.xlabel('Grupo de Simulações (Runs)')
plt.ylabel('Média de Score')

# Rotaciona os rótulos do eixo X para evitar sobreposição
plt.xticks(rotation=45, ha='right')

# Ajusta o layout para que os rótulos não sejam cortados
plt.tight_layout()


# --- Passo 5: Salvar o gráfico ---
plt.savefig('grafico_barras_grupos_Main.png')

# Se desejar exibir o gráfico na tela ao rodar localmente:
# plt.show()

print("Gráfico de barras dos grupos gerado e salvo como 'grafico_barras_grupos_Main.png'")
# Out:
# Gráfico de barras dos grupos gerado e salvo como 'grafico_barras_grupos_Main.png'

# %%
df = pd.read_csv('simulacao-BuscaBfs.csv')


# --- Passo 2: Calcular a média de 'Score' a cada 10 runs ---
df['run_group'] = (df.index // 10)
average_scores = df.groupby('run_group')['Score'].mean()


# --- Passo 3: Preparar os dados para o gráfico ---
# Criar uma lista de rótulos descritivos para o eixo X do gráfico
group_labels = [f'Runs {i*10+1}-{(i+1)*10}' for i in average_scores.index]


# --- Passo 4: Criar o gráfico de barras dos grupos ---
plt.figure(figsize=(10, 6))

# Usamos os rótulos que criamos no eixo X e as médias no eixo Y
plt.bar(group_labels, average_scores, color='teal')

# Adiciona uma linha horizontal no zero
plt.axhline(0, color='grey', linewidth=0.8)

# Adiciona títulos e rótulos
plt.title('Média de Score por Grupo de 10 Simulações Greedy')
plt.xlabel('Grupo de Simulações (Runs)')
plt.ylabel('Média de Score')

# Rotaciona os rótulos do eixo X para evitar sobreposição
plt.xticks(rotation=45, ha='right')

# Ajusta o layout para que os rótulos não sejam cortados
plt.tight_layout()


# --- Passo 5: Salvar o gráfico ---
plt.savefig('grafico_barras_grupos_Greedy.png')

# Se desejar exibir o gráfico na tela ao rodar localmente:
# plt.show()

print("Gráfico de barras dos grupos gerado e salvo como 'grafico_barras_grupos_Greedy.png'")
# Out:
# Gráfico de barras dos grupos gerado e salvo como 'grafico_barras_grupos_Greedy.png'

# %%
df = pd.read_csv('simulacao-BuscaDijkstra.csv')


# --- Passo 2: Calcular a média de 'Score' a cada 10 runs ---
df['run_group'] = (df.index // 10)
average_scores = df.groupby('run_group')['Score'].mean()


# --- Passo 3: Preparar os dados para o gráfico ---
# Criar uma lista de rótulos descritivos para o eixo X do gráfico
group_labels = [f'Runs {i*10+1}-{(i+1)*10}' for i in average_scores.index]


# --- Passo 4: Criar o gráfico de barras dos grupos ---
plt.figure(figsize=(10, 6))

# Usamos os rótulos que criamos no eixo X e as médias no eixo Y
plt.bar(group_labels, average_scores, color='teal')

# Adiciona uma linha horizontal no zero
plt.axhline(0, color='grey', linewidth=0.8)

# Adiciona títulos e rótulos
plt.title('Média de Score por Grupo de 10 Simulações Dijkstra')
plt.xlabel('Grupo de Simulações (Runs)')
plt.ylabel('Média de Score')

# Rotaciona os rótulos do eixo X para evitar sobreposição
plt.xticks(rotation=45, ha='right')

# Ajusta o layout para que os rótulos não sejam cortados
plt.tight_layout()


# --- Passo 5: Salvar o gráfico ---
plt.savefig('grafico_barras_grupos_Dijkstra.png')

# Se desejar exibir o gráfico na tela ao rodar localmente:
# plt.show()

print("Gráfico de barras dos grupos gerado e salvo como 'grafico_barras_grupos_Dijkstra.png'")
# Out:
# Gráfico de barras dos grupos gerado e salvo como 'grafico_barras_grupos_Dijkstra.png'

# %%
df = pd.read_csv('simulacao-DefaultPlayer-Pausa.csv')


# --- Passo 2: Calcular a média de 'Score' a cada 10 runs ---
df['run_group'] = (df.index // 10)
average_scores = df.groupby('run_group')['Score'].mean()


# --- Passo 3: Preparar os dados para o gráfico ---
# Criar uma lista de rótulos descritivos para o eixo X do gráfico
group_labels = [f'Runs {i*10+1}-{(i+1)*10}' for i in average_scores.index]


# --- Passo 4: Criar o gráfico de barras dos grupos ---
plt.figure(figsize=(10, 6))

# Usamos os rótulos que criamos no eixo X e as médias no eixo Y
plt.bar(group_labels, average_scores, color='teal')

# Adiciona uma linha horizontal no zero
plt.axhline(0, color='grey', linewidth=0.8)

# Adiciona títulos e rótulos
plt.title('Média de Score por Grupo de 10 Simulações Pausa')
plt.xlabel('Grupo de Simulações (Runs)')
plt.ylabel('Média de Score')

# Rotaciona os rótulos do eixo X para evitar sobreposição
plt.xticks(rotation=45, ha='right')

# Ajusta o layout para que os rótulos não sejam cortados
plt.tight_layout()


# --- Passo 5: Salvar o gráfico ---
plt.savefig('grafico_barras_grupos_pausa.png')

# Se desejar exibir o gráfico na tela ao rodar localmente:
# plt.show()

print("Gráfico de barras dos grupos gerado e salvo como 'grafico_barras_grupos_pausa.png'")
# Out:
# Gráfico de barras dos grupos gerado e salvo como 'grafico_barras_grupos_pausa.png'

# %%
df = pd.read_csv('simulacao-MultiCargo.csv')


# --- Passo 2: Calcular a média de 'Score' a cada 10 runs ---
df['run_group'] = (df.index // 10)
average_scores = df.groupby('run_group')['Score'].mean()


# --- Passo 3: Preparar os dados para o gráfico ---
# Criar uma lista de rótulos descritivos para o eixo X do gráfico
group_labels = [f'Runs {i*10+1}-{(i+1)*10}' for i in average_scores.index]


# --- Passo 4: Criar o gráfico de barras dos grupos ---
plt.figure(figsize=(10, 6))

# Usamos os rótulos que criamos no eixo X e as médias no eixo Y
plt.bar(group_labels, average_scores, color='teal')

# Adiciona uma linha horizontal no zero
plt.axhline(0, color='grey', linewidth=0.8)

# Adiciona títulos e rótulos
plt.title('Média de Score por Grupo de 10 Simulações MultiCargo')
plt.xlabel('Grupo de Simulações (Runs)')
plt.ylabel('Média de Score')

# Rotaciona os rótulos do eixo X para evitar sobreposição
plt.xticks(rotation=45, ha='right')

# Ajusta o layout para que os rótulos não sejam cortados
plt.tight_layout()


# --- Passo 5: Salvar o gráfico ---
plt.savefig('grafico_barras_grupos_mult.png')

# Se desejar exibir o gráfico na tela ao rodar localmente:
# plt.show()

print("Gráfico de barras dos grupos gerado e salvo como 'grafico_barras_grupos_mult.png'")
# Out:
# Gráfico de barras dos grupos gerado e salvo como 'grafico_barras_grupos_mult.png'

# %%
df = pd.read_csv('simulacao-SmartPlayer-As.csv')


# --- Passo 2: Calcular a média de 'Score' a cada 10 runs ---
df['run_group'] = (df.index // 10)
average_scores = df.groupby('run_group')['Score'].mean()


# --- Passo 3: Preparar os dados para o gráfico ---
# Criar uma lista de rótulos descritivos para o eixo X do gráfico
group_labels = [f'Runs {i*10+1}-{(i+1)*10}' for i in average_scores.index]


# --- Passo 4: Criar o gráfico de barras dos grupos ---
plt.figure(figsize=(10, 6))

# Usamos os rótulos que criamos no eixo X e as médias no eixo Y
plt.bar(group_labels, average_scores, color='teal')

# Adiciona uma linha horizontal no zero
plt.axhline(0, color='grey', linewidth=0.8)

# Adiciona títulos e rótulos
plt.title('Média de Score por Grupo de 10 Simulações SmartPlayer-As')
plt.xlabel('Grupo de Simulações (Runs)')
plt.ylabel('Média de Score')

# Rotaciona os rótulos do eixo X para evitar sobreposição
plt.xticks(rotation=45, ha='right')

# Ajusta o layout para que os rótulos não sejam cortados
plt.tight_layout()


# --- Passo 5: Salvar o gráfico ---
plt.savefig('grafico_barras_grupos_SmartPlayer_As.png')

# Se desejar exibir o gráfico na tela ao rodar localmente:
# plt.show()

print("Gráfico de barras dos grupos gerado e salvo como 'grafico_barras_grupos_SmartPlayer_As.png'")
# Out:
# Gráfico de barras dos grupos gerado e salvo como 'grafico_barras_grupos_SmartPlayer_As.png'

# %%
df = pd.read_csv('simulacao-SmartPlayer-Dijkstra.csv')


# --- Passo 2: Calcular a média de 'Score' a cada 10 runs ---
df['run_group'] = (df.index // 10)
average_scores = df.groupby('run_group')['Score'].mean()


# --- Passo 3: Preparar os dados para o gráfico ---
# Criar uma lista de rótulos descritivos para o eixo X do gráfico
group_labels = [f'Runs {i*10+1}-{(i+1)*10}' for i in average_scores.index]


# --- Passo 4: Criar o gráfico de barras dos grupos ---
plt.figure(figsize=(10, 6))

# Usamos os rótulos que criamos no eixo X e as médias no eixo Y
plt.bar(group_labels, average_scores, color='teal')

# Adiciona uma linha horizontal no zero
plt.axhline(0, color='grey', linewidth=0.8)

# Adiciona títulos e rótulos
plt.title('Média de Score por Grupo de 10 Simulações SmartPlayer-Dijkstra')
plt.xlabel('Grupo de Simulações (Runs)')
plt.ylabel('Média de Score')

# Rotaciona os rótulos do eixo X para evitar sobreposição
plt.xticks(rotation=45, ha='right')

# Ajusta o layout para que os rótulos não sejam cortados
plt.tight_layout()


# --- Passo 5: Salvar o gráfico ---
plt.savefig('grafico_barras_grupos_SmartPlayer_Dijkstra.png')

# Se desejar exibir o gráfico na tela ao rodar localmente:
# plt.show()

print("Gráfico de barras dos grupos gerado e salvo como 'grafico_barras_grupos_SmartPlayer_Dijkstra.png'")
# Out:
# Gráfico de barras dos grupos gerado e salvo como 'grafico_barras_grupos_SmartPlayer_Dijkstra.png'

# %%
df = pd.read_csv('simulacao-SmartPlayer-Greedy.csv')


# --- Passo 2: Calcular a média de 'Score' a cada 10 runs ---
df['run_group'] = (df.index // 10)
average_scores = df.groupby('run_group')['Score'].mean()


# --- Passo 3: Preparar os dados para o gráfico ---
# Criar uma lista de rótulos descritivos para o eixo X do gráfico
group_labels = [f'Runs {i*10+1}-{(i+1)*10}' for i in average_scores.index]


# --- Passo 4: Criar o gráfico de barras dos grupos ---
plt.figure(figsize=(10, 6))

# Usamos os rótulos que criamos no eixo X e as médias no eixo Y
plt.bar(group_labels, average_scores, color='teal')

# Adiciona uma linha horizontal no zero
plt.axhline(0, color='grey', linewidth=0.8)

# Adiciona títulos e rótulos
plt.title('Média de Score por Grupo de 10 Simulações SmartPlayer-Greedy')
plt.xlabel('Grupo de Simulações (Runs)')
plt.ylabel('Média de Score')

# Rotaciona os rótulos do eixo X para evitar sobreposição
plt.xticks(rotation=45, ha='right')

# Ajusta o layout para que os rótulos não sejam cortados
plt.tight_layout()


# --- Passo 5: Salvar o gráfico ---
plt.savefig('grafico_barras_grupos_SmartPlayer_Greedy.png')

# Se desejar exibir o gráfico na tela ao rodar localmente:
# plt.show()

print("Gráfico de barras dos grupos gerado e salvo como 'grafico_barras_grupos_SmartPlayer_Greedy.png'")
# Out:
# Gráfico de barras dos grupos gerado e salvo como 'grafico_barras_grupos_SmartPlayer_Greedy.png'

# %%
df = pd.read_csv('simulacao-SmartPlayer-Prioridade.csv')


# --- Passo 2: Calcular a média de 'Score' a cada 10 runs ---
df['run_group'] = (df.index // 10)
average_scores = df.groupby('run_group')['Score'].mean()


# --- Passo 3: Preparar os dados para o gráfico ---
# Criar uma lista de rótulos descritivos para o eixo X do gráfico
group_labels = [f'Runs {i*10+1}-{(i+1)*10}' for i in average_scores.index]


# --- Passo 4: Criar o gráfico de barras dos grupos ---
plt.figure(figsize=(10, 6))

# Usamos os rótulos que criamos no eixo X e as médias no eixo Y
plt.bar(group_labels, average_scores, color='teal')

# Adiciona uma linha horizontal no zero
plt.axhline(0, color='grey', linewidth=0.8)

# Adiciona títulos e rótulos
plt.title('Média de Score por Grupo de 10 Simulações SmartPlayer-Prioridade')
plt.xlabel('Grupo de Simulações (Runs)')
plt.ylabel('Média de Score')

# Rotaciona os rótulos do eixo X para evitar sobreposição
plt.xticks(rotation=45, ha='right')

# Ajusta o layout para que os rótulos não sejam cortados
plt.tight_layout()


# --- Passo 5: Salvar o gráfico ---
plt.savefig('grafico_barras_grupos_SmartPlayer_Prioridade.png')

# Se desejar exibir o gráfico na tela ao rodar localmente:
# plt.show()

print("Gráfico de barras dos grupos gerado e salvo como 'grafico_barras_grupos_SmartPlayer_Prioridade.png'")
# Out:
# Gráfico de barras dos grupos gerado e salvo como 'grafico_barras_grupos_SmartPlayer_Prioridade.png'
